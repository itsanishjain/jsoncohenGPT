# %%
links = [
  "https://longform.asmartbear.com/jason-cohen/",
  "https://longform.asmartbear.com/product-market-fit-formula/",
  "https://longform.asmartbear.com/problem/",
  "https://longform.asmartbear.com/extreme-questions/",
  "https://longform.asmartbear.com/startup-beats-incumbent/",
  "https://longform.asmartbear.com/fulfillment/",
  "https://longform.asmartbear.com/predict-the-future/",
  "https://longform.asmartbear.com/exponential-growth/",
  "https://longform.asmartbear.com/more-value-not-save-money/",
  "https://longform.asmartbear.com/icp-ideal-customer-persona/",
  "https://longform.asmartbear.com/product-market-fit/",
  "https://longform.asmartbear.com/customer-development/",
  "https://longform.asmartbear.com/willingness-to-pay/",
  "https://longform.asmartbear.com/great-strategy/",
  "https://longform.asmartbear.com/roi-rubric/",
  "https://longform.asmartbear.com/slc/",
  "https://longform.asmartbear.com/rocks-pebbles-sand/",
  "https://longform.asmartbear.com/leverage/",
  "https://longform.asmartbear.com/needs-stack/",
  "https://longform.asmartbear.com/survivor-bias/",
  "https://longform.asmartbear.com/impostor-syndrome/",
  "https://longform.asmartbear.com/real-company/",
  "https://longform.asmartbear.com/pricing-determines-your-business-model/",
  "https://longform.asmartbear.com/in-command/",
  "https://longform.asmartbear.com/say-yes/",
  "https://longform.asmartbear.com/rich-vs-king-sold-company/",
  "https://longform.asmartbear.com/maximized-decision/",
  "https://longform.asmartbear.com/product-metrics/",
  "https://longform.asmartbear.com/failure-to-face-the-truth/",
  "https://longform.asmartbear.com/consulting-company-accounting/",
  "https://longform.asmartbear.com/jit-backlogs/",
  "https://longform.asmartbear.com/startups-emotionally-draining/",
  "https://longform.asmartbear.com/decisions-fast-slow/",
  "https://longform.asmartbear.com/bad-advice/",
  "https://longform.asmartbear.com/moats/",
  "https://longform.asmartbear.com/great-product-manager/",
  "https://longform.asmartbear.com/emptiness/",
  "https://longform.asmartbear.com/ai-startups/",
  "https://longform.asmartbear.com/investment/",
  "https://longform.asmartbear.com/good-problems-to-have/",
  "https://longform.asmartbear.com/top-10/",
  "https://longform.asmartbear.com/strategic-planning/",
  "https://longform.asmartbear.com/unmeasurable-metrics/",
  "https://longform.asmartbear.com/scale/",
  "https://longform.asmartbear.com/fail/",
  "https://longform.asmartbear.com/worse-but-unique/",
  "https://longform.asmartbear.com/probability-words/",
  "https://longform.asmartbear.com/talk-vs-walk/",
  "https://longform.asmartbear.com/productive-meeting-activities/",
  "https://longform.asmartbear.com/whos-lying/",
  "https://longform.asmartbear.com/distributed-logical-time/",
  "https://longform.asmartbear.com/change/",
  "https://longform.asmartbear.com/maximizing/",
  "https://longform.asmartbear.com/building-in-public/",
  "https://longform.asmartbear.com/forecast/",
  "https://longform.asmartbear.com/utilization/",
  "https://longform.asmartbear.com/success-guaranteed/",
  "https://longform.asmartbear.com/scale-rare/",
  "https://longform.asmartbear.com/more-money/",
  "https://longform.asmartbear.com/two-big-things/",
  "https://longform.asmartbear.com/identity-selling-sadness/",
  "https://longform.asmartbear.com/roi-selling/",
  "https://longform.asmartbear.com/startup-life/",
  "https://longform.asmartbear.com/good-startup-ideas/",
  "https://longform.asmartbear.com/learn-by-copy/",
  "https://longform.asmartbear.com/first-competitive-advantage/",
  "https://longform.asmartbear.com/criticize-create/",
  "https://longform.asmartbear.com/be-yourself/",
  "https://longform.asmartbear.com/color-wheels/",
  "https://longform.asmartbear.com/reputation/",
  "https://longform.asmartbear.com/pattern-seeking-fallacy/",
  "https://longform.asmartbear.com/one-benefit/",
  "https://longform.asmartbear.com/sacrifice-your-health-for-your-startup/",
  "https://longform.asmartbear.com/letters-to-joel-spolsky/",
  "https://longform.asmartbear.com/ab-testing-statistics/",
  "https://longform.asmartbear.com/double-your-productivity/",
  "https://longform.asmartbear.com/procrastinate/",
  "https://longform.asmartbear.com/hello-support/",
  "https://longform.asmartbear.com/discount-gambit/",
];

# %%
links[0]
# Out:
# 'https://longform.asmartbear.com/jason-cohen/'

# %%
import requests
from bs4 import BeautifulSoup

# Array to store the content of each webpage
content = []

# Iterate through each link
for link in links:
    try:
        # Fetch the webpage
        response = requests.get(link)
        
        # Check if request was successful
        if response.status_code == 200:
            # Parse the HTML content
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Extract all text content from the webpage
            text_content = soup.get_text()
            
            # Append the content to the array
            content.append(text_content)
        else:
            print(f"Failed to fetch {link}. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while fetching {link}: {e}")

# Print the content array
print(content)
# Out:
# ["\n\n\n\nJason Cohen: About the author\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLinkCopied\n\n\n\n\n\n\n\n\nA Smart Bear\xa0\xa0»\xa0\xa0Jason Cohen: About the author\n\n\n\n\n\nAll Articles\n\n\nAuthor\n\n\n\n\n\nMoon\n\nSun\n\n\n\n\n\n\n\n\n\n\n\n\nAll Articles\n\n\nAuthor\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJason Cohen: About the author\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTwitter | LinkedIn | Mastodon | Threads\nThanks for visiting! As a four-time entrepreneur across 24 years, both bootstrapped and VC-funded, resulting in two exits and two unicorns, I’ve also been writing about everything I know for 17 years. I hope you’ll find it useful and entertaining.\nMostly to support a new startup, I occasionally do short advisory calls through TalkWithMe.\nFounder \nWP Engine \nCurrently I’m the Chief Innovation Officer of WP Engine, which I started in 2010, bootstrapped for two years, then raised a few small rounds, then t
# ...

# %%
len(content)
# Out:
# 79

# %%
len(links)
# Out:
# 79

# %%
content[0]
# Out:
# "\n\n\n\nJason Cohen: About the author\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLinkCopied\n\n\n\n\n\n\n\n\nA Smart Bear\xa0\xa0»\xa0\xa0Jason Cohen: About the author\n\n\n\n\n\nAll Articles\n\n\nAuthor\n\n\n\n\n\nMoon\n\nSun\n\n\n\n\n\n\n\n\n\n\n\n\nAll Articles\n\n\nAuthor\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJason Cohen: About the author\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTwitter | LinkedIn | Mastodon | Threads\nThanks for visiting! As a four-time entrepreneur across 24 years, both bootstrapped and VC-funded, resulting in two exits and two unicorns, I’ve also been writing about everything I know for 17 years. I hope you’ll find it useful and entertaining.\nMostly to support a new startup, I occasionally do short advisory calls through TalkWithMe.\nFounder \nWP Engine \nCurrently I’m the Chief Innovation Officer of WP Engine, which I started in 2010, bootstrapped for two years, then raised a few small rounds, then to
# ...

# %%
import re

# Function to clean HTML tags from the content
def clean_html_tags(text):
    clean_text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    return clean_text

# Function to remove special characters and extra whitespaces
def clean_special_characters(text):
    # Define a list of special characters to remove
    special_characters = ['\n', '\t', '\r']
    
    # Remove special characters
    for char in special_characters:
        text = text.replace(char, ' ')
    
    # Remove extra whitespaces
    clean_text = re.sub(r'\s+', ' ', text).strip()
    
    return clean_text

# Process each item in the content array
cleaned_content = []
for item in content:
    # Clean HTML tags
    cleaned_text = clean_html_tags(item)
    
    # Remove special characters and extra whitespaces
    cleaned_text = clean_special_characters(cleaned_text)
    
    # Append cleaned text to the new array
    cleaned_content.append(cleaned_text)

# %%
len(cleaned_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 len(cleaned_content)
#
# NameError: name 'cleaned_content' is not defined

# %%
cleaned_content[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cleaned_content[0]
#
# NameError: name 'cleaned_content' is not defined

# %%
# %pip install -qU langchain-text-splitters
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# poetry 1.1.12 requires cachecontrol[filecache]<0.13.0,>=0.12.9; python_version >= "3.6" and python_version < "4.0", but you have cachecontrol 0.13.1 which is incompatible.
# poetry 1.1.12 requires cleo<0.9.0,>=0.8.1, but you have cleo 2.0.1 which is incompatible.
# poetry 1.1.12 requires crashtest<0.4.0,>=0.3.0; python_version >= "3.6" and python_version < "4.0", but you have crashtest 0.4.1 which is incompatible.
# poetry 1.1.12 requires keyring<22.0.0,>=21.2.0; python_version >= "3.6" and python_version < "4.0", but you have keyring 24.2.0 which is incompatible.
# poetry 1.1.12 requires packaging<21.0,>=20.4, but you have packaging 23.2 which is incompatible.
# poetry 1.1.12 requires poetry-core<1.1.0,>=1.0.7, but you have poetry-core 1.7.0 which is incompatible.
# ...

# %%
# Specify the file path where you want to save the cleaned content
file_path = "cleaned_content.txt"

# Open the file in write mode
with open(file_path, 'w', encoding='utf-8') as file:
    # Write each cleaned text content to the file
    for text in cleaned_content:
        file.write(text + '\n')

print(f"Cleaned content has been saved to '{file_path}'.")
# Out:
# Cleaned content has been saved to 'cleaned_content.txt'.

# %%
len(cleaned_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 len(cleaned_data)
#
# NameError: name 'cleaned_data' is not defined

# %%
# Specify the file path from which you want to fetch the cleaned content
file_path = "cleaned_content.txt"

# List to store the fetched content
fetched_content = []

# Open the file in read mode
with open(file_path, 'r', encoding='utf-8') as file:
    # Read each line from the file
    for line in file:
        # Append the line to the fetched content list (removing trailing newline character)
        fetched_content.append(line.rstrip())

# %%
fetched_content[10]
# Out:
# "Product/Market Fit (PMF): Experience & Data LinkCopied A Smart Bear » Product/Market Fit (PMF): Experience & Data All Articles Author Moon Sun All Articles Author Subscribe Jason Cohen November 5, 2023 Reading time: 11 min Printable PDF Product/Market Fit (PMF): Experience & Data by Jason Cohen on November 5, 2023 Companies that achieve Product/Market Fit – both self-funded and VC-funded – exhibit the same prototypical metrics curves and subjective experiences. source Every day people debate how to define “Product/Market Fit.” It’s best to start with the subjective experience, because there is no doubt when you have it. (If you’re not sure whether you have Product/Market Fit, you don’t.) If every day it’s a struggle to get customers, it’s not working yet. If every day it’s a struggle to keep up with demand, it’s working. It is a momentum change from “push” to “pull”—a change from fighting for each customer, one at a time, to a flood of signups that you can’t even explain. It’s a cha
# ...

# %%
len(fetched_content)
# Out:
# 79

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len,
    is_separator_regex=False,
)

# %%
texts = text_splitter.create_documents(fetched_content)
print(texts[0])
print(texts[1])
# Out:
# page_content='Jason Cohen: About the author LinkCopied A Smart Bear » Jason Cohen: About the author All Articles Author Moon Sun All Articles Author Jason Cohen: About the author Twitter | LinkedIn | Mastodon | Threads Thanks for visiting! As a four-time entrepreneur across 24 years, both bootstrapped and VC-funded, resulting in two exits and two unicorns, I’ve also been writing about everything I know for 17 years. I hope you’ll find it useful and entertaining. Mostly to support a new startup, I occasionally do short advisory calls through TalkWithMe. Founder WP Engine Currently I’m the Chief Innovation Officer of WP Engine, which I started in 2010, bootstrapped for two years, then raised a few small rounds, then together with our amazing CEO Heather Brunner a few large rounds totaling over $300M, fueled hyper-growth to a unicorn with 1,200 employees across eight global offices, serving many billions of web requests daily for 200,000 customers as one of the top-ten largest web platf
# ...

# %%
len(texts)
# Out:
# 1306

# %%
texts[-1]
# Out:
# Document(page_content='privacy. Drop me a line on Twitter, LinkedIn, Mastodon, or Threads. © 2007-2024 Jason Cohen')

# %%
texts[len(texts)-15]
# Out:
# Document(page_content='before the product explodes in popularity and prices go up. And I’m rewarded for this support and')

# %%
fetched_content[-1]
# Out:
# "Discount gambit LinkCopied A Smart Bear » Discount gambit All Articles Author Moon Sun All Articles Author Subscribe Jason Cohen March 22, 2008 Reading time: 5 min Printable PDF Discount gambit by Jason Cohen on March 22, 2008 Discounting is the typical sales technique, but refusing to discount can lead to a much better business, even in the Enterprise. source Which of these pricing strategies is more persuasive? If you buy now, I’ll give you a discount. The price is going up, but if you buy now I will lock in your rate. Both are types of discount. The typical software sales strategy is #1. It’s often applied to get the customer to “close” before the end of the month or quarter or some other arbitrary time boundary. At first blush it seems harder to persuade with #2. After all, #1 means the customer pays less than #2, because #2 isn’t a real discount—it’s a discount against an imagined future price. But for me, the evidence is overwhelmingly in favor of #2. Here’s why, from the poin
# ...

# %%
# Specify the file path where you want to save the chunked content
output_file_path = "chunked_content.txt"

# Open the file in write mode
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    # Write each chunked item to the file
    for chunk in texts:
        output_file.write(chunk + '\n')

print(f"Chunked content has been saved to '{output_file_path}'.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 8
#       5 with open(output_file_path, 'w', encoding='utf-8') as output_file:
#       6     # Write each chunked item to the file
#       7     for chunk in texts:
# ----> 8         output_file.write(chunk + '\n')
#      10 print(f"Chunked content has been saved to '{output_file_path}'.")
#
# TypeError: unsupported operand type(s) for +: 'Document' and 'str'

# %%
texts0[]
# Out:
#   Cell In[31], line 1
#     texts0[]
#            ^
# SyntaxError: invalid syntax

# %%
texts[0]
# Out:
# Document(page_content='Jason Cohen: About the author LinkCopied A Smart Bear » Jason Cohen: About the author All Articles Author Moon Sun All Articles Author Jason Cohen: About the author Twitter | LinkedIn | Mastodon | Threads Thanks for visiting! As a four-time entrepreneur across 24 years, both bootstrapped and VC-funded, resulting in two exits and two unicorns, I’ve also been writing about everything I know for 17 years. I hope you’ll find it useful and entertaining. Mostly to support a new startup, I occasionally do short advisory calls through TalkWithMe. Founder WP Engine Currently I’m the Chief Innovation Officer of WP Engine, which I started in 2010, bootstrapped for two years, then raised a few small rounds, then together with our amazing CEO Heather Brunner a few large rounds totaling over $300M, fueled hyper-growth to a unicorn with 1,200 employees across eight global offices, serving many billions of web requests daily for 200,000 customers as one of the top-ten largest 
# ...

# %%
text_splitter.split_text(fetched_content[0])[:2]
# Out:
# ['Jason Cohen: About the author LinkCopied A Smart Bear » Jason Cohen: About the author All Articles Author Moon Sun All Articles Author Jason Cohen: About the author Twitter | LinkedIn | Mastodon | Threads Thanks for visiting! As a four-time entrepreneur across 24 years, both bootstrapped and VC-funded, resulting in two exits and two unicorns, I’ve also been writing about everything I know for 17 years. I hope you’ll find it useful and entertaining. Mostly to support a new startup, I occasionally do short advisory calls through TalkWithMe. Founder WP Engine Currently I’m the Chief Innovation Officer of WP Engine, which I started in 2010, bootstrapped for two years, then raised a few small rounds, then together with our amazing CEO Heather Brunner a few large rounds totaling over $300M, fueled hyper-growth to a unicorn with 1,200 employees across eight global offices, serving many billions of web requests daily for 200,000 customers as one of the top-ten largest web platforms in the'
# ...

# %%
texts[3]
# Out:
# Document(page_content='that didn’t work out, but I’m no less proud to have been a small part of the journey.) Speaker Some folks enjoy my talks on bootstrapping and startups over the past decade. These are the favorites: Designing the Ideal Bootstrapped Business Video from Microconf 2013 Healthy, Wealthy, and Wise (lessons in burn-out on the way to $100M ARR) Video from Business of Software 2017; Video from SaaStr Feb 2018 How data makes you do the wrong thing Video from Business of Software 2012 Naked Business: How Honesty Makes Money Video from Business of Software 2011, or YouTube from Microconf 2012 A Geek Sifts Through the Bullshit Video from WebStock 2011 When to break the rules and ignore advice Video from Business of Software 2010 Special links Single PDF with all articles, newest first. RSS in “newsletter” order, both new articles and cleaned-up older posts. RSS in published-date order, newest first. Credits The cartoons are by the prolific Mark Anderson of Andertoons. This 
# ...

# %%
text_splitter.split_text(fetched_content[1])[:2]
# Out:
# ['The roadmap to Product/Market Fit (PMF)… maybe LinkCopied A Smart Bear » The roadmap to Product/Market Fit (PMF)… maybe All Articles Author Moon Sun All Articles Author Subscribe Jason Cohen December 24, 2023 Reading time: 31 min Printable PDF The roadmap to Product/Market Fit (PMF)… maybe by Jason Cohen on December 24, 2023 This eight-step process brought WP Engine from an idea to a Unicorn. While there are other roads to Product/Market Fit, consider copying some of these ideas. source What is the formula for going from an initial product idea to Product/Market Fit—a company that is growing and sustainable, with customers that want to pay and want to stay. (Assuming you even agree with that definition of Product/Market Fit.) There isn’t a fail-safe roadmap of course, but there is a progression that describes how WP Engine became a unicorn, supported by 17 years of articles from this site. Here’s what that progression looks like. Then we’ll explore the other truth—that it often doe
# ...

# %%
typeof(texts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 typeof(texts)
#
# NameError: name 'typeof' is not defined

# %%
type(texts)
# Out:
# list

# %%
texts[0]
# Out:
# Document(page_content='Jason Cohen: About the author LinkCopied A Smart Bear » Jason Cohen: About the author All Articles Author Moon Sun All Articles Author Jason Cohen: About the author Twitter | LinkedIn | Mastodon | Threads Thanks for visiting! As a four-time entrepreneur across 24 years, both bootstrapped and VC-funded, resulting in two exits and two unicorns, I’ve also been writing about everything I know for 17 years. I hope you’ll find it useful and entertaining. Mostly to support a new startup, I occasionally do short advisory calls through TalkWithMe. Founder WP Engine Currently I’m the Chief Innovation Officer of WP Engine, which I started in 2010, bootstrapped for two years, then raised a few small rounds, then together with our amazing CEO Heather Brunner a few large rounds totaling over $300M, fueled hyper-growth to a unicorn with 1,200 employees across eight global offices, serving many billions of web requests daily for 200,000 customers as one of the top-ten largest 
# ...

# %%
type(texts[0])
# Out:
# langchain_core.documents.base.Document

# %%
# List to store the chunked content
chunked_content = []

# Split each item in the cleaned content array
for index, text in enumerate(fetched_content):
    # Split the text into chunks
    chunks = text_splitter.split_text(text)
    
    # Store the chunks with metadata
    for chunk in chunks:
        chunked_content.append({
            "pageTitle": links[index],
            "chunk": chunk,
            "originalContent": text
        })

# Specify the file path where you want to save the chunked content
output_file_path = "chunked_content.txt"

# Open the file in write mode
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    # Write each chunked item to the file
    for chunk_data in chunked_content:
        # Convert dictionary to string and write to file
        output_file.write(str(chunk_data) + '\n')

print(f"Chunked content has been saved to '{output_file_path}'.")
# Out:
# Chunked content has been saved to 'chunked_content.txt'.

# %%
# chunked_content[0]

# %%
len(chunked_content)
# Out:
# 1306

# %%
# chunked_content[1]

# %%
# !pip install --upgrade astrapy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 KB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 1.5 MB/s eta 0:00:002.0 MB/s eta 0:00:01
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 3.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 KB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 2.5 MB/s eta 0:00:00
# ...

# %%
from astrapy.db import AstraDB

# Initialize the client
db = AstraDB(
  token=YOUR_TOKEN,
  api_endpoint="https://792559d6-1bdf-437a-a9d0-92cfea201a2b-us-east-1.apps.astra.datastax.com")

print(f"Connected to Astra DB: {db.get_collections()}")
# Out:
# Connected to Astra DB: {'status': {'collections': []}}

# %%
# !pip install OpenAI
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 KB 1.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...

# %%
from openai import OpenAI
client = OpenAI(api_key=YOUR_KEY)

# %%
'''
Src - https://platform.openai.com/docs/guides/embeddings/use-cases

In general, using the dimensions parameter when 
creating the embedding is the suggested approach. 
In certain cases, you may need to change the embedding 
dimension after you generate it. When you change the dimension manually, 
you need to be sure to normalize the 
dimensions of the embedding as is shown below.'''
# Out:
# '\nSrc - https://platform.openai.com/docs/guides/embeddings/use-cases\n\nIn general, using the dimensions parameter when \ncreating the embedding is the suggested approach. \nIn certain cases, you may need to change the embedding \ndimension after you generate it. When you change the dimension manually, \nyou need to be sure to normalize the \ndimensions of the embedding as is shown below.'

# %%
def get_embedding(text, model="text-embedding-3-small"):
    text = text.replace("\n", " ")
    return client.embeddings.create(input=[text], model=model,dimensions=256).data[0].embedding

def embed_chunks(chunked_content):
    for item in chunked_content:
        chunk_text = item['chunk']
        embedding = get_embedding(chunk_text)
        item['embedding'] = embedding

# %%
# embed_chunks(chunked_content[1202:])

# %%
len(chunked_content)
# Out:
# 1306

# %%
a = get_embedding("incumbents")

# %%
# a

# %%
a
# Out:
# [0.01988276280462742,
#  0.03025231510400772,
#  0.11764616519212723,
#  0.01768740639090538,
#  0.12250397354364395,
#  0.00472546461969614,
#  0.062341880053281784,
#  0.022950032725930214,
#  -0.04512156918644905,
#  0.013288909569382668,
#  0.10051927715539932,
#  -0.005823142826557159,
#  0.012121167033910751,
#  -0.004877271130681038,
#  0.13427481055259705,
#  0.003857442643493414,
#  -0.00043984968215227127,
#  -0.023541688919067383,
#  0.06732425093650818,
#  0.16703388094902039,
#  -0.018964137881994247,
#  -0.0074969069100916386,
#  0.030594853684306145,
#  -0.0024366893339902163,
#  -0.03876905143260956,
#  0.11920315772294998,
#  -0.14536058902740479,
#  -0.02282547391951084,
#  0.11266379803419113,
#  -0.0020124095026403666,
#  0.09628426283597946,
#  -0.0726180151104927,
#  -0.041042257100343704,
#  -0.09223608672618866,
#  0.11752160638570786,
#  0.12829597294330597,
#  -0.050072796642780304,
#  -0.022171538323163986,
#  0.018310202285647392,
#  -0.02168887108564377,
# ...

# %%
def check_embedding_existence(chunked_content):
    for index,item in enumerate(chunked_content):
        if 'embedding' not in item:
            print(f"Embedding not found for chunk with pageTitle: {item['pageTitle']}",index)
            break
            # Here you can perform any other actions you want for chunks without embedding

# %%
check_embedding_existence(chunked_content)
# Out:
# Embedding not found for chunk with pageTitle: https://longform.asmartbear.com/color-wheels/ 1202

# %%
list(chunked_content[1202].keys())
# Out:
# ['pageTitle', 'chunk', 'originalContent', 'embedding']

# %%
len(chunked_content[1202]['embedding'])
# Out:
# 1536

# %%
chunked_content[0].keys()
# Out:
# dict_keys(['pageTitle', 'chunk', 'originalContent', 'embedding'])

# %%
import sys
# Calculate the size of the array in bytes
array_size_bytes = sys.getsizeof(chunked_content)

# Convert bytes to megabytes (1 MB = 1024 * 1024 bytes)
array_size_mb = array_size_bytes / (1024 * 1024)

print(f"Size of array: {array_size_mb:.2f} MB")
# Out:
# Size of array: 0.01 MB

# %%
db
# Out:
# AstraDB[endpoint="https://792559d6-1bdf-437a-a9d0-92cfea201a2b-us-east-1.apps.astra.datastax.com", keyspace="default_keyspace"]

# %%
# Create a collection. The default similarity metric is "cosine".
collection = db.create_collection("vectorsmall", dimension=256, metric="cosine")
print(collection)
# Out:
# AstraDBCollection[astra_db="AstraDB[endpoint="https://792559d6-1bdf-437a-a9d0-92cfea201a2b-us-east-1.apps.astra.datastax.com", keyspace="default_keyspace"]", collection_name="vectorsmall"]

# %%
# res = collection.insert_many(chunked_content)
# print(res)

# %%
import numpy as np

# %%
def normalize_l2(x):
    x = np.array(x)
    if x.ndim == 1:
        norm = np.linalg.norm(x)
        if norm == 0:
            return x.tolist()  # Convert NumPy array to plain Python list
        return (x / norm).tolist()  # Convert NumPy array to plain Python list
    else:
        norm = np.linalg.norm(x, 2, axis=1, keepdims=True)
        return np.where(norm == 0, x, (x / norm)).tolist()  # Convert NumPy array to plain Python list

# %%
def update_embeddings(chunked_content):
    for item in chunked_content:
        if 'embedding' in item:
            item['embedding'] = normalize_l2(item['embedding'][:256])

# %%
# Update embeddings
update_embeddings(chunked_content)

# %%
# (chunked_content[0]['embedding'])

# %%
chunked_content[0:2]
# Out:
# [{'pageTitle': 'https://longform.asmartbear.com/jason-cohen/',
# ...

# %%
# Assuming 'chunked_content' is a list of dictionaries

# Define the maximum batch size
batch_size = 10  # You can adjust this value based on your requirements

# Calculate the number of batches
num_batches = (len(chunked_content) + batch_size - 1) // batch_size

# Insert documents in batches
for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = min((i + 1) * batch_size, len(chunked_content))
    batch = chunked_content[start_idx:end_idx]
    res = collection.insert_many(batch)
    print(f"Inserted {len(res)} documents in batch {i+1}/{num_batches}")

# Optionally print the response
# print(res)
# Out:
# Inserted 1 documents in batch 1/131
# Inserted 1 documents in batch 2/131
# Inserted 1 documents in batch 3/131
# Inserted 1 documents in batch 4/131
# Inserted 1 documents in batch 5/131
# Inserted 1 documents in batch 6/131
# Inserted 1 documents in batch 7/131
# Inserted 1 documents in batch 8/131
# Inserted 1 documents in batch 9/131
# Inserted 1 documents in batch 10/131
# Inserted 1 documents in batch 11/131
# Inserted 1 documents in batch 12/131
# Inserted 1 documents in batch 13/131
# Inserted 1 documents in batch 14/131
# Inserted 1 documents in batch 15/131
# Inserted 1 documents in batch 16/131
# Inserted 1 documents in batch 17/131
# Inserted 1 documents in batch 18/131
# Inserted 1 documents in batch 19/131
# Inserted 1 documents in batch 20/131
# Inserted 1 documents in batch 21/131
# Inserted 1 documents in batch 22/131
# Inserted 1 documents in batch 23/131
# Inserted 1 documents in batch 24/131
# Inserted 1 documents in batch 25/131
# ...

# %%
def update_embeddings(chunked_content):
    for item in chunked_content:
        if 'embedding' in item:
            # Rename the 'embedding' key to '$vector'
            item['$vector'] = item.pop('embedding')
            # Remove the 'originalContent' field
            item.pop('originalContent', None)

# %%
update_embeddings(chunked_content)

# %%
chunked_content[0]
# Out:
# {'pageTitle': 'https://longform.asmartbear.com/jason-cohen/',
# ...
